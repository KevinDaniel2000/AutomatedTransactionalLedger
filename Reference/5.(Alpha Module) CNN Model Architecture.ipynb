# %% [markdown]
# ## IMPORTING DEPENDENCIES

# %%
#Importing to build a network
import tensorflow as tf
from tensorflow.keras import layers, models
#Importing for mathematical calculations
import matplotlib.pyplot as plt
import numpy as np
import random
#importing to access local files
import os
#pre-process the image
import cv2
#to track the status
from tqdm import tqdm
# %matplotlib inline

from keras.models import load_model

# %% [markdown]
# ## PATH OF DATASET training set | validation set

# %%
# PATH of dataset
DATADIR_1 = "C:/Users/kevin/Desktop/Project_Resources/indian_currency_new/training"                 #path of main folder
CATEGORIES_1 = ["10", "20", "50", "100", "200", "500", "2000", "Background"]      #path of sub folder
DATADIR_2 = "C:/Users/kevin/Desktop/Project_Resources/indian_currency_new/validation"               #path of main folder
CATEGORIES_2 = ["10", "20", "50", "100", "200", "500", "2000", "Background"]      #path of sub folder

# %% [markdown]
# ## CROSS-CHECKING THE IMAGE

# %%
#Image check
temp = cv2.imread("C:/Users/kevin/Desktop/indian_currency_new/training/2000/3.jpg",cv2.IMREAD_COLOR)  # convert to array
temp = cv2.resize(temp, (120, 68))             # resize to normalize data size
#training_data.append([new_array_1, class_num_1])
plt.imshow(temp)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-74800bb19f52> in <module>
#       1 #Image check
#       2 temp = cv2.imread("C:/Users/kevin/Desktop/indian_currency_new/training/2000/3.jpg",cv2.IMREAD_COLOR)  # convert to array
# ----> 3 temp = cv2.resize(temp, (120, 68))             # resize to normalize data size
#       4 #training_data.append([new_array_1, class_num_1])
#       5 plt.imshow(temp)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-kh7iq4w7\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %% [markdown]
# ## IMPORTING DATA FOR TRAINING

# %%
# IMPORTING TRAINING DATASET
training_data = []
def create_training_data():
    for category_1 in CATEGORIES_1:
        path_1 = os.path.join(DATADIR_1,category_1)
        class_num_1 = CATEGORIES_1.index(category_1)  # get the classification  (0 or a 1). 1=dog 0=cat
        for img_1 in tqdm(os.listdir(path_1)):        # iterate over each image per dogs and cats
            try:
                img_array_1 = cv2.imread(os.path.join(path_1,img_1) ,cv2.IMREAD_COLOR)  # convert to array
                new_array_1 = cv2.resize(img_array_1, (120, 68))                        # resize to normalize data size
                training_data.append([new_array_1, class_num_1])                        # add this to our training_data
            except Exception_1 as e_1:
                pass
create_training_data()     #calling the function
print("no of images imported for training : "+str(len(training_data)))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 87/87 [00:05<00:00, 14.94it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 75/75 [00:03<00:00, 19.45it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 46.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 85/85 [00:01<00:00, 72.44it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 84/84 [00:01<00:00, 44.71it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 84/84 [00:01<00:00, 78.21it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 84/84 [00:01<00:00, 58.90it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 220/220 [00:05<00:00, 36.81it/s]
# no of images imported for training : 798

# %% [markdown]
# ## IMPORTING DATA FOR TESTING

# %%
#IMPORTING TEST DATASET
testing_data = []
def create_testing_data():
    for category_2 in CATEGORIES_2:
        path_2 = os.path.join(DATADIR_2,category_2)
        class_num_2 = CATEGORIES_2.index(category_2)  # get the classification  (0 or a 1). 1=dog 0=cat
        for img_2 in tqdm(os.listdir(path_2)):        # iterate over each image per dogs and cats
            try:
                img_array_2 = cv2.imread(os.path.join(path_2,img_2) ,cv2.IMREAD_COLOR)  # convert to array
                new_array_2 = cv2.resize(img_array_2, (120, 68))                        # resize to normalize data size
                testing_data.append([new_array_2, class_num_2])                         # add this to our testing_data
            except Exception_2 as e_2:
                pass
create_testing_data()     #calling the function
print("no of images imported for testing  : "+str(len(testing_data)))
print("   ")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:01<00:00, 14.57it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:01<00:00, 20.66it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 55.27it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 61.45it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 42.01it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 76.72it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 66.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:01<00:00, 23.60it/s]
# no of images imported for testing  : 191

# %%
#random shuffling
random.shuffle(training_data)
random.shuffle(testing_data)

# %% [markdown]
# ## RE-SHAPING THE IMAGE DIMENSIONS

# %%
# RESHAPING VALUES AND LABELS of train
X_1 = [] # X_1 = values of TRAIN SET
y_1 = [] # y_1 = labels of TRAIN SET
for features_1,label_1 in training_data:
    X_1.append(features_1)
    y_1.append(label_1)
X_1 = np.array(X_1).reshape(-1, 120, 68, 3)
train_set_y=np.matrix(y_1)

# RESHAPING VALUES AND LABELS of test
X_2 = [] # X_2 = values of TEST SET
y_2 = [] # y_2 = labels of TEST SET
for features_2,label_2 in testing_data:
    X_2.append(features_2)
    y_2.append(label_2)
X_2 = np.array(X_2).reshape(-1, 120, 68, 3)
test_set_y=np.matrix(y_2)

print("shape of values of training : "+str(X_1.shape))
print("shape of values of testing  : "+str(X_2.shape))
print("shape of labels of training : "+str(train_set_y.shape))
print("shape of labels of testing  : "+str(test_set_y.shape))
print("  ")
# Out:
# shape of values of training : (798, 120, 68, 3)
# shape of values of testing  : (191, 120, 68, 3)
# shape of labels of training : (1, 798)
# shape of labels of testing  : (1, 191)

# %%
#flattening the image array
train_set_x_flatten = X_1.reshape(X_1.shape[0],-1).T
test_set_x_flatten  = X_2.reshape(X_2.shape[0],-1).T

#dividing with pexel value for better perfomance
train_set_x = train_set_x_flatten/255.
test_set_x = test_set_x_flatten/255.
#print(X_1)

print ("train value flatten shape    : " + str(train_set_x_flatten.shape))
print ("test value flatten shape     : " + str(test_set_x_flatten.shape))
print ("train label shape            : " + str(train_set_y.shape))
print ("test label shape             : " + str(test_set_y.shape))
print ("sanity check after reshaping : " + str(train_set_x_flatten[0:5,0]))
print("  ")
# Out:
# train value flatten shape    : (24480, 798)
# test value flatten shape     : (24480, 191)
# train label shape            : (1, 798)
# test label shape             : (1, 191)
# sanity check after reshaping : [213 212 222 210 209]

# %%
X_train = train_set_x
X_test = test_set_x
#print(X_train)
#print(y_train)
#print(train_set_y)
y_train = train_set_y

# %% [markdown]
# ## FRAMING LAYERS convolution | dense

# %%
# 4-Convolutional Layers | 2-Dense Layers 
cnn = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(120, 68, 3)),
    layers.MaxPooling2D((2, 2)),
    
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    #layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    #layers.MaxPooling2D((2, 2)),
    
    #layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    #layers.MaxPooling2D((2, 2)),
    
    layers.Flatten(),
    layers.Dense(100, activation='relu'),
    layers.Dense(8, activation='softmax')
])

cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 118, 66, 32)       896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 59, 33, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 57, 31, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 15, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 6, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 4, 64)         36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 640)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               64100
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 808
# =================================================================
# Total params: 158,156
# Trainable params: 158,156
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## DEFINING MODEL loss | optimizers | metrics

# %%
#cnn.compile(optimizer='adam',
#              loss='sparse_categorical_crossentropy',
#              metrics=['accuracy'])

#Defining model optimizers, loss function and metrics
cnn.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
#np.transpose(y_train)
#X_train = X_1.reshape(X_1.shape[0], -1)
y_train = train_set_y.reshape(train_set_y.shape[0], -1).T
#y_train = y_train.reshape(-1,)
#print(y_train)
#print(X_train)

#np.transpose(y_train)
X_train = X_1.reshape(X_1.shape[0], -1)
y_test = test_set_y.reshape(test_set_y.shape[0], -1).T
#y_train = y_train.reshape(-1,)
#print(y_train)
#print(X_train)

# %% [markdown]
# ## RE-CHECKING DATA DIMENSIONS

# %%
print(X_train.shape)
print(y_train.shape)

print(X_train.ndim)
print(y_train.ndim)

print(type(X_train.ndim))
print(type(y_train.ndim))
print(X_1.shape) #Required shape | no of images, Width, Height, no of Colour Chanels
# Out:
# (798, 24480)
# (798, 1)
# 2
# 2
# <class 'int'>
# <class 'int'>
# (798, 120, 68, 3)

# %%
tf.config.run_functions_eagerly(True)

# %% [markdown]
# ## COMPILE MODEL

# %%
#Callback Function
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.8):
            print("\n Model has Reached 80% accuracy so cancelling training")
            self.model.stop_training = True
            
callbacks = myCallback()

# %%
model_metrics = cnn.fit(X_1, y_train, epochs=40, callbacks=[callbacks], validation_data=(X_2, y_test))
#cnn.fit(X_1, y_train, epochs=5, batch_size=4)
# Out:
# C:\Users\kevin\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:3503: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   warnings.warn(
# Epoch 1/40
# 25/25 [==============================] - 10s 397ms/step - loss: 13.5099 - accuracy: 0.1599 - val_loss: 2.2967 - val_accuracy: 0.1204
# Epoch 2/40
# 25/25 [==============================] - 10s 411ms/step - loss: 2.0881 - accuracy: 0.2280 - val_loss: 2.1882 - val_accuracy: 0.1309
# Epoch 3/40
# 25/25 [==============================] - 10s 390ms/step - loss: 1.9378 - accuracy: 0.2742 - val_loss: 1.9087 - val_accuracy: 0.2513
# Epoch 4/40
# 25/25 [==============================] - 9s 368ms/step - loss: 1.6644 - accuracy: 0.4029 - val_loss: 1.6083 - val_accuracy: 0.3717
# Epoch 5/40
# 25/25 [==============================] - 10s 409ms/step - loss: 1.6077 - accuracy: 0.3851 - val_loss: 1.5812 - val_accuracy: 0.3927
# Epoch 6/40
# 25/25 [==============================] - 12s 495ms/step - loss: 1.4324 - accuracy: 0.4391 - val_loss: 1.3584 - val_accuracy: 0.5707
# Epoch 7/40
# 25/25 [==============================] - 11s 442ms/step - loss: 1.2417 - accuracy: 0.5812 - val_loss: 1.6681 - val_accuracy: 0.4241
# Epoch 8/40
# 25/25 [==============================] - 10s 403ms/step - loss: 1.4048 - accuracy: 0.5103 - val_loss: 1.4745 - val_accuracy: 0.3979
# Epoch 9/40
# 25/25 [==============================] - 11s 426ms/step - loss: 1.3361 - accuracy: 0.5199 - val_loss: 1.3900 - val_accuracy: 0.5602
# Epoch 10/40
# 25/25 [==============================] - 11s 445ms/step - loss: 1.1112 - accuracy: 0.6028 - val_loss: 1.1368 - val_accuracy: 0.6283
# Epoch 11/40
# 25/25 [==============================] - 14s 557ms/step - loss: 1.0449 - accuracy: 0.6172 - val_loss: 1.3083 - val_accuracy: 0.5759
# Epoch 12/40
# 25/25 [==============================] - 14s 538ms/step - loss: 1.1594 - accuracy: 0.5770 - val_loss: 1.3342 - val_accuracy: 0.5602
# Epoch 13/40
# 25/25 [==============================] - 11s 448ms/step - loss: 0.9752 - accuracy: 0.6561 - val_loss: 1.0257 - val_accuracy: 0.6597
# Epoch 14/40
# 25/25 [==============================] - 11s 447ms/step - loss: 0.7652 - accuracy: 0.7504 - val_loss: 1.2106 - val_accuracy: 0.5550
# Epoch 15/40
# 25/25 [==============================] - 12s 482ms/step - loss: 0.7581 - accuracy: 0.7432 - val_loss: 1.0400 - val_accuracy: 0.6963
# Epoch 16/40
# 25/25 [==============================] - 12s 485ms/step - loss: 0.7663 - accuracy: 0.7386 - val_loss: 1.2249 - val_accuracy: 0.6702
# Epoch 17/40
# 25/25 [==============================] - 11s 454ms/step - loss: 0.7876 - accuracy: 0.7302 - val_loss: 1.3966 - val_accuracy: 0.5340
# Epoch 18/40
# 25/25 [==============================] - 11s 454ms/step - loss: 0.8211 - accuracy: 0.7093 - val_loss: 1.1000 - val_accuracy: 0.6806
# Epoch 19/40
# 25/25 [==============================] - 12s 465ms/step - loss: 0.6695 - accuracy: 0.7797 - val_loss: 1.0745 - val_accuracy: 0.6911
# Epoch 20/40
# 25/25 [==============================] - 12s 475ms/step - loss: 0.7421 - accuracy: 0.7501 - val_loss: 1.0100 - val_accuracy: 0.7382
# Epoch 21/40
# 25/25 [==============================] - 12s 466ms/step - loss: 0.5690 - accuracy: 0.8152 - val_loss: 1.1455 - val_accuracy: 0.7644
# Epoch 22/40
# 25/25 [==============================] - 12s 473ms/step - loss: 0.6290 - accuracy: 0.7747 - val_loss: 1.0098 - val_accuracy: 0.7801
# Epoch 23/40
# 25/25 [==============================] - 14s 548ms/step - loss: 0.5053 - accuracy: 0.8168 - val_loss: 0.9747 - val_accuracy: 0.7801
#
#  Model has Reached 80% accuracy so cancelling training

# %% [markdown]
# ## PLOTTING MODEL'S METRICS

# %%
# summarize history for accuracy
plt.plot(model_metrics.history['accuracy'])
plt.plot(model_metrics.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(model_metrics.history['loss'])
plt.plot(model_metrics.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## DISPLAYING MODEL METRICS

# %%
train_loss, train_acc = cnn.evaluate(X_1,  y_train, verbose=2)
test_loss, test_acc = cnn.evaluate(X_2,  y_test, verbose=2)

training_accuracy = train_acc*100
training_loss = train_loss*100

validation_accuracy = test_acc*100
validation_loss = test_loss*100

print(" ")
print("Training Accuracy = ",int(training_accuracy),'%')
#print("Training Loss = ",int(training_loss),'%')

print("Validation Accuracy = ",int(validation_accuracy),'%')
#print("Validation Loss = ",int(validation_loss),'%')
# Out:
# 25/25 - 3s - loss: 0.4578 - accuracy: 0.8521
# 6/6 - 1s - loss: 0.9747 - accuracy: 0.7801
#
# Training Accuracy =  85 %
# Validation Accuracy =  78 %

# %% [markdown]
# ## WRAPPING UP TO TEST OUR INPUT

# %%
def Final_Prediction(file_name):
    label = 0
    my_image = file_name    #path of image
    print("File name is : " , my_image )
    fname = "C:/Users/kevin/Desktop/TEST/" + my_image
    reading_image = cv2.imread(fname ,cv2.IMREAD_COLOR)  # convert to array
    plt.imshow(reading_image) # Displaying image
    resized_image = cv2.resize(reading_image, (120, 68))
    image_array = np.array(resized_image).reshape(-1, 120, 68, 3)
    #print(x.shape)
    my_predicted_image = cnn.predict(image_array)
    print(" ")
    print("Predicted values in output layer : " )
    print(my_predicted_image)
    # using argmax
    label_inside=np.argmax(my_predicted_image)
    print(" ")
    print("Predicted Label : " , label_inside)
    label = label_inside
    print("__________________________________________________________________________________________")
    
    if label==0:
        print("The image is calssified  as 10 Rupees")
    elif label==1:
        print("The image is calssified  as 20 Rupees") 
    elif label==2:
        print("The image is calssified  as 50 Rupees")
    elif label==3:
        print("The image is calssified  as 100 Rupees")
    elif label==4:
        print("The image is calssified  as 200 Rupees")
    elif label==5:
        print("The image is calssified  as 500 Rupees")
    elif label==6:
        print("The image is calssified  as 2000 Rupees")
    else:
        print("Please input valid rupees image")

# %% [markdown]
# ## TESTING OUR OWN DATA

# %%
Final_Prediction("2000.jpg") #input file name with format
# Out:
# File name is :  2000.jpg
#
# Predicted values in output layer :
# [[3.7480489e-04 3.6040701e-02 8.8801637e-04 2.9702743e-03 1.2646065e-04
#   5.9162567e-06 9.5908111e-01 5.1269564e-04]]
#
# Predicted Label :  6
# __________________________________________________________________________________________
# The image is calssified  as 2000 Rupees

# %% [markdown]
# ## SAVING MODEL

# %%
cnn.save('CNN_Multi_Class.h5')

# %% [markdown]
# ## LOAD MODEL

# %%
#cnn=load_model('./CNN_Multi_Class.h5')
    # or
#cnn = tf.keras.models.load_model('CNN_Multi_Class.h5')
